# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
vidio = pd.read_csv('streaming_video.csv')

# %%
vidio
# Out:
#                                            link video duration_label  \
# 0   https://www.vidio.com/watch/1896401-ep-01-mae-...          42:54
# 1   https://www.vidio.com/watch/1902475-ep-02-gara...            NaN
# 2   https://www.vidio.com/watch/1907292-ep-03-si-g...          47:58
# 3   https://www.vidio.com/watch/1911431-ep-04-buka...            NaN
# 4   https://www.vidio.com/watch/1914423-ep-05-mae-...          44:19
# 5   https://www.vidio.com/watch/1918315-ep-06-sela...            NaN
# 6   https://www.vidio.com/watch/1921810-ep-07-cint...            NaN
# 7   https://www.vidio.com/watch/1925490-ep-08-pert...          49:32
# 8   https://www.vidio.com/watch/1929006-ep-09-hati...          44:53
# 9   https://www.vidio.com/watch/1933077-ep-10-takd...            NaN
# 10  https://www.vidio.com/watch/1937916-ep-11-keti...          45:55
# 11  https://www.vidio.com/watch/1942439-ep-12-siag...            NaN
# 12  https://www.vidio.com/watch/1947019-ep-13-mae-...          40:45
#
# ...

# %%
! pip install textblob

# %%
from textblob import TextBlob

vidio.loc[8,'description']
# Out:
# 'Apa jadinya kalau keluarga Mae tinggal di rumah Rendy?'

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 8]

for index, title in enumerate(vidio.index):
  x = vidio.polarity.loc[title]
  y = vidio.subjectivity.loc[title]
  plt.scatter(x, y, color='blue')
  plt.xlim(-1,1)

plt.title('Sentiment Analysis')
plt.xlabel('Polarity', fontsize=15)
plt.ylabel('Subjectivity', fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9684\1372636569.py in ?()
#       1 import matplotlib.pyplot as plt
#       2 plt.rcParams['figure.figsize'] = [10, 8]
#       3
#       4 for index, title in enumerate(vidio.index):
# ----> 5   x = vidio.polarity.loc[title]
#       6   y = vidio.subjectivity.loc[title]
#       7   plt.scatter(x, y, color='blue')
#       8   plt.xlim(-1,1)
#
# e:\Anacondaa\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'polarity'
