# %% [markdown]
# ## Assignment Computer Vision About Object Detection & Tracking

# %% [markdown]
# Create an automatic camera program that will capture images from a webcam only when it detects a smiling person's face. If it detects a person's face and is smiling, capture the image and save it to a file.
#
# ---
