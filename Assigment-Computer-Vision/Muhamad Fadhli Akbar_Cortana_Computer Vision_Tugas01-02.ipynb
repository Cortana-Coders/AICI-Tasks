# %% [markdown]
# ## Computer Vision Assignment 01-02
# **Muhamad Fadhli Akbar(Cortana)**
#
# ---

# %% [markdown]
# **Tugas CV 1-2**
#
# 1. Kamu diberikan sebuah gambar tes buta warna, namun kamu kesulitan untuk menentukan angka yang berada pada gambar tersebut. Gunakanlah CV untuk memperjelas angka yang terdapat pada gambar `hint: channel`
#
# ---

# %%
! pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB 991.0 kB/s eta 0:00:40
#    ---------------------------------------- 0.1/38.8 MB 1.4 MB/s eta 0:00:27
#    ---------------------------------------- 0.3/38.8 MB 2.1 MB/s eta 0:00:19
#     --------------------------------------- 0.5/38.8 MB 2.6 MB/s eta 0:00:15
#     --------------------------------------- 0.9/38.8 MB 4.0 MB/s eta 0:00:10
#     --------------------------------------- 1.0/38.8 MB 3.4 MB/s eta 0:00:12
#    - -------------------------------------- 1.1/38.8 MB 3.4 MB/s eta 0:00:12
#    - -------------------------------------- 1.3/38.8 MB 3.4 MB/s eta 0:00:12
#    - -------------------------------------- 1.5/38.8 MB 3.8 MB/s eta 0:00:10
#    - -------------------------------------- 1.6/38.8 MB 3.6 MB/s eta 0:00:11
#    - -------------------------------------- 1.7/38.8 MB 3.5 MB/s eta 0:00:11
# ...

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
img = cv2.imread('tesbutawarna.jpg')

# %%
img
# Out:
# array([[[245, 245, 245],
#         [245, 245, 245],
#         [245, 245, 245],
#         ...,
#         [245, 245, 245],
#         [245, 245, 245],
#         [245, 245, 245]],
#
#        [[245, 245, 245],
#         [245, 245, 245],
#         [245, 245, 245],
#         ...,
#         [245, 245, 245],
#         [245, 245, 245],
#         [245, 245, 245]],
#
#        [[245, 245, 245],
#         [245, 245, 245],
#         [245, 245, 245],
#         ...,
#         [245, 245, 245],
#         [245, 245, 245],
#         [245, 245, 245]],
#
#        ...,
#
#        [[245, 245, 245],
#         [245, 245, 245],
#         [245, 245, 245],
#         ...,
#         [245, 245, 245],
#         [245, 245, 245],
#         [245, 245, 245]],
#
#        [[245, 245, 245],
#         [245, 245, 245],
#         [245, 245, 245],
#         ...,
#         [245, 245, 245],
#         [245, 245, 245],
#         [245, 245, 245]],
#
#        [[245, 245, 245],
#         [245, 245, 245],
#         [245, 245, 245],
# ...

# %%
pic = Image.open('tesbutawarna.jpg')

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)
pic_arr.shape
# Out:
# (191, 200, 3)

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x191>

# %%
pic_bgr = cv2.imread('tesbutawarna.jpg')
plt.imshow(pic_bgr)

# %%
img_gray = cv2.imread('tesbutawarna.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# 2. Terdapat sebuah gambar anjing. Berilah tambahan gambar berupa teks `I love Dog` dengan
# ‘love’ berupa symbol. (contoh tertera)
#
# ---

# %%
sample_dog_image = cv2.imread('doggo.jpg')

# %%
sample_dog_image
# Out:
# array([[[80, 74, 69],
#         [79, 73, 68],
#         [77, 71, 66],
#         ...,
#         [27, 28, 24],
#         [26, 27, 23],
#         [26, 27, 23]],
#
#        [[63, 57, 52],
#         [59, 55, 50],
#         [59, 53, 48],
#         ...,
#         [27, 28, 24],
#         [27, 28, 24],
#         [26, 27, 23]],
#
#        [[44, 39, 36],
#         [41, 38, 34],
#         [39, 34, 31],
#         ...,
#         [26, 27, 23],
#         [26, 27, 23],
#         [26, 27, 23]],
#
#        ...,
#
#        [[17, 25, 18],
#         [17, 25, 18],
#         [18, 26, 19],
#         ...,
#         [16, 23, 16],
#         [17, 25, 18],
#         [19, 27, 20]],
#
#        [[22, 29, 22],
#         [20, 27, 20],
#         [20, 27, 20],
#         ...,
#         [17, 24, 17],
#         [19, 26, 19],
#         [20, 27, 20]],
#
#        [[22, 29, 22],
#         [21, 28, 21],
#         [21, 28, 21],
#         ...,
#         [19, 26, 19],
#         [21, 28, 21],
#         [22, 29, 22]]], dtype=uint8)

# %%
! pip install Pillow

# %%
from PIL import Image, ImageFont,ImageDraw, ImageFont
import emoji

# %%
sample_dog_cv = cv2.imread('doggo.jpg')

# %%
plt.imshow(sample_dog_cv)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
# Koordinat (x,y) dan (x,y) adalah koordinat titik awal dari text
cv2.putText(sample_dog_cv,text='I',org=(25,40),fontFace=font,fontScale= 1,color=(255,255,255),thickness=1,lineType=cv2.LINE_AA)
plt.imshow(sample_dog_cv)

# %%
# Koordinat (x,y) dan (x,y) adalah koordinat titik awal dari text
cv2.putText(sample_dog_cv,text='Dog',org=(10,100),fontFace=font,fontScale= 0.8,color=(255,255,255),thickness=1,lineType=cv2.LINE_AA)
plt.imshow(sample_dog_cv)

# %% [markdown]
# Contoh Output
#
# <img src="image.png">

# %%
height, width, _ = sample_dog_cv.shape

# Define the center and size of the heart
center_x, center_y = width // 6, height // 2
heart_size = min(width, height) // 7

# Draw the left circle
cv2.circle(img=sample_dog_cv, center=(center_x - heart_size // 2, center_y - heart_size // 4), radius=heart_size // 2, color=(255, 0, 0), thickness=-1)

# Draw the right circle
cv2.circle(img=sample_dog_cv, center=(center_x + heart_size // 2, center_y - heart_size // 4), radius=heart_size // 2, color=(255, 0, 0), thickness=-1)

# Draw the bottom part of the heart using a polygon
points = np.array([
    [center_x - heart_size, center_y - heart_size // 6],
    [center_x + heart_size, center_y - heart_size // 6],
    [center_x, center_y + heart_size]
], np.int32)
points = points.reshape((-1, 1, 2))
cv2.fillPoly(sample_dog_cv, [points], color=(255, 0, 0))

# Display the image
plt.imshow(sample_dog_cv)
plt.axis('off')  # Hide the axes
plt.show()
