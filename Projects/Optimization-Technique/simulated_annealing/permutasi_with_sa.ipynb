# %% [markdown]
# ## Permutations in Personal Computer Components

# %%
import random
import math
from itertools import permutations

# %%
class SimulatedAnnealing:
    def __init__(self, varRanges, numOfInitSolution, maxIter, stoppingValue, minTemp):
        self.components = components
        self.varRanges = varRanges
        self.numOfInitSolution = numOfInitSolution
        self.maxIter = maxIter
        self.stoppingValue = stoppingValue
        self.minTemp = minTemp
    
    def getInitSolution(self):

        solutionRepresentation = []

        for _ in range(len(self.components)):
            solutionRepresentation.append(random.randint(0,1))
        return solutionRepresentation
    
    def calcObjFunction(self, solutionRepresentation):
        total = 0
        for i in range(len(solutionRepresentation)):
            if solutionRepresentation[i] == 1:
                total += self.components[i]

    def mainSA(self):
        temperature = 1000
        solRep = self.getInitSolution()
        print(self.getInitSolution)

# %%
location = 9
components = [
    ["Monitor MSI 34WAQ", "Monitor A", ""],
    ["Monitor MSI 34WAQ", "Monitor A", ""],
    ["Monitor MSI 34WAQ", "Monitor A", ""],
    ["Monitor MSI 34WAQ", "Monitor A", ""],
    ["Ram Ssamsung EVO6200MHZ", "", ""],
    ["Hardisk 2TB", "", ""],
    ["Intel I7 1200HK", "", ""],
    ["ROG Fan Cooler", "", ""],
]

distanceMatrix = [
    [10, 203 ,12, 212, 2],
    [10, 203 ,12, 212, 2],
    [10, 203 ,12, 212, 2],
    [10, 203 ,12, 212, 2],
]

varRanges = [-5, 5]
numOfInitSolution = 4
maxIter = 5
stoppingValue = 0.005
minTemp = 1
# solusi awal
# (0,6,1,2,3,4,5)
# Hitung jarak  0 ke 6 lalu 1 ..N kemudian di total
# (0, 1, 2, 4, 5, 6, 7, 3) Total = 120
# (2, 6, 2, 4, 5, 1, 7, 3) Total = 142
