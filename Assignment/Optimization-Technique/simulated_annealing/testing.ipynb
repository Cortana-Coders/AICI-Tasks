# %%
import sys
import random
from itertools import permutations
from math import exp

# %%
def getDistance(distanceLibrary, a, b):
    if (a, b) in distanceLibrary:

        print(distanceLibrary[(a,b)])

        return distanceLibrary[(a, b)]
    elif (b, a) in distanceLibrary:

        print(distanceLibrary[(b, a)])

        return distanceLibrary[(b, a)]
    else:
        return 0

# %%
# Data komponen
distanceLibrary = {
    (0, 1): 4.4, (0, 2): 1.8, (0, 3): 3.4, (0, 4): 0.65, (0, 5): 0.70, (0, 6): 36,
    (1, 2): 3.3, (1, 3): 2.2, (1, 4): 4.9, (1, 5): 4, (1, 6): 34,
    (2, 3): 2, (2, 4): 2.9, (2, 5): 1.9, (2, 6): 35,
    (3, 4): 3.7, (3, 5): 2.8, (3, 6): 35,
    (4, 5): 0.9, (4, 6): 37,
    (5, 6): 36
}
varRanges = [-5, 5]
numOfInitSolution = 5
maxIter = 15
stoppingValue = 0.0001
minTemp = 0.01

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 getDistance()
#
# TypeError: getDistance() missing 3 required positional arguments: 'self', 'a', and 'b'
